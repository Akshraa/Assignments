# %%
import pandas as pd

# %%
df=pd.DataFrame({'SID':[11,12,13,14,15],
                'Sname':['Giri','Siri','Ram','Radha','Jyoti'],
                'age':[18,19,21,20,19],
                'sem':[1,2,2,1,2],
                'Dname':['CSE','Mech','ECE','BCA','BCA']})
df
# Out:
#    SID  Sname  age  sem Dname
# 0   11   Giri   18    1   CSE
# 1   12   Siri   19    2  Mech
# 2   13    Ram   21    2   ECE
# 3   14  Radha   20    1   BCA
# 4   15  Jyoti   19    2   BCA

# %%
df=pd.DataFrame({'SID':[11,12,13,14,15], 'Sname':['Giri','Siri','Ram','Radha','Jyoti'],
                'age':[18,19,21,20,19],
                'sem':[1,2,2,1,2],
                'Dname':['CSE','Mech','ECE','BCA','BCA']})
df
# Out:
#    SID  Sname  age  sem Dname
# 0   11   Giri   18    1   CSE
# 1   12   Siri   19    2  Mech
# 2   13    Ram   21    2   ECE
# 3   14  Radha   20    1   BCA
# 4   15  Jyoti   19    2   BCA

# %%
df
# Out:
#    SID  Sname  age  sem Dname
# 0   11   Giri   18    1   CSE
# 1   12   Siri   19    2  Mech
# 2   13    Ram   21    2   ECE
# 3   14  Radha   20    1   BCA
# 4   15  Jyoti   19    2   BCA

# %%
######################

# %%
#slicing:
#iloc: integer location
#loc: lable based

# %%
df.iloc[:,:]
# Out:
#    SID  Sname  age  sem Dname
# 0   11   Giri   18    1   CSE
# 1   12   Siri   19    2  Mech
# 2   13    Ram   21    2   ECE
# 3   14  Radha   20    1   BCA
# 4   15  Jyoti   19    2   BCA

# %%
df.iloc[0:2,:]
# Out:
#    SID Sname  age  sem Dname
# 0   11  Giri   18    1   CSE
# 1   12  Siri   19    2  Mech

# %%
#here first[0:2] represents the rows and after comma[:] that means we didn't select any coloumn

# %%
df.iloc[0:2,0:2]
# Out:
#    SID Sname
# 0   11  Giri
# 1   12  Siri

# %%
df.loc[:,:]
# Out:
#    SID  Sname  age  sem Dname
# 0   11   Giri   18    1   CSE
# 1   12   Siri   19    2  Mech
# 2   13    Ram   21    2   ECE
# 3   14  Radha   20    1   BCA
# 4   15  Jyoti   19    2   BCA

# %%
df.loc[0:2,'SID':'age']
# Out:
#    SID Sname  age
# 0   11  Giri   18
# 1   12  Siri   19
# 2   13   Ram   21

# %%
df.loc[0:2,['SID','Dname']]
# Out:
#    SID Dname
# 0   11   CSE
# 1   12  Mech
# 2   13   ECE

# %%
import pandas as pd
df2=pd.DataFrame({'SID':[11,12,13,14,15],
                'Sname':['Giri','Siri','Ram','Radha','Jyoti'],
                'age':[18,19,21,20,19],
                'sem':[1,2,2,1,2],
                'Dname':['CSE','Mech','ECE','BCA','BCA']},
                 index=['a','b','c','d','e'])
df2
# Out:
#    SID  Sname  age  sem Dname
# a   11   Giri   18    1   CSE
# b   12   Siri   19    2  Mech
# c   13    Ram   21    2   ECE
# d   14  Radha   20    1   BCA
# e   15  Jyoti   19    2   BCA

# %%
df2.iloc[0:3,0:3]
# Out:
#    SID Sname  age
# a   11  Giri   18
# b   12  Siri   19
# c   13   Ram   21

# %%
df2.loc['a':'c','SID':'age']
# Out:
#    SID Sname  age
# a   11  Giri   18
# b   12  Siri   19
# c   13   Ram   21

# %%
df2.iloc[[0,4]]
# Out:
#    SID  Sname  age  sem Dname
# a   11   Giri   18    1   CSE
# e   15  Jyoti   19    2   BCA

# %%
df2.iloc[[1,2]]
# Out:
#    SID Sname  age  sem Dname
# b   12  Siri   19    2  Mech
# c   13   Ram   21    2   ECE

# %%
df2.iloc[1:2,0:2]
# Out:
#    SID Sname
# b   12  Siri

# %%
df2.iloc[1:3,0:2]
# Out:
#    SID Sname
# b   12  Siri
# c   13   Ram
